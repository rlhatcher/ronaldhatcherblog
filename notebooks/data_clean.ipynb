# %% [markdown]
# # Data Cleaning Notebook
#
# ## Introduction
#
# This notebook outlines the process of cleaning a dataset. The purpose is to prepare the data for further analysis by handling missing values, correcting inconsistencies, and normalizing data.
#
# ### Goals:
#
# - **Understand** the structure of the dataset.
# - **Identify** and handle missing or inconsistent data.
# - **Prepare** the dataset for graph.

# %% [markdown]
# ## Imports and utility functions

# %%
import pandas as pd
import numpy as np

# %%
def filter_columns_by_non_null_count(df, non_null_threshold=10):
    """
    Filter columns in a DataFrame based on a threshold of non-null values.

    Parameters:
    df (pd.DataFrame): The DataFrame to be filtered.
    non_null_threshold (int): The minimum number of non-null values required to keep a column.

    Returns:
    pd.DataFrame: A new DataFrame containing only the columns with non-null values above the threshold.
    """
    filtered_columns = [
        col for col in df.columns if df[col].count() > non_null_threshold]
    return df[filtered_columns]

# %% [markdown]
# ## Data Loading
#
# Here we load the data from its source, which could be a CSV file, database, or other formats.

# %%
df_e = pd.read_csv('./data_raw/estes_kits_details.csv', quotechar="'")
df_l = pd.read_csv('./data_raw/loc_kits_details.csv', quotechar="'")

df_manufacturers = pd.read_csv('./data_raw/manufacturers.csv')
df_motors = pd.read_csv('./data_raw/rocket_motors.csv')

# %% [markdown]
# ## Data Inspection
#
# In this section, we inspect the dataset for inconsistencies, missing values, and anomalies.

# %%
df_motors.head()
# Out:
#   commonName delays  diameter  \
# 0    1/8A0.3      1       6.0
# 1    1/8A0.3      1       6.0
# 2      1/4A2    2,4      10.5
# 3      1/4A3      3      13.0
# 4      1/2A3    2,4      13.0
#
#                                             infoUrl  totImpulseNs  \
# 0  http://www.nar.org/SandT/pdf/Quest/MicroMaxx.pdf         0.135
# 1                                               NaN         0.218
# 2         http://nar.org/SandT/pdf/Apogee/qtrA2.pdf         0.570
# 3          http://nar.org/SandT/pdf/Estes/qtrA3.pdf         0.590
# 4        http://nar.org/SandT/pdf/Estes/halfA3T.pdf         1.090
#
#         manufacturer  burnTimeS      propInfo  length  avgThrustN  ...  \
# 0    Quest Aerospace      0.827  black powder    26.0       0.163  ...
# 1    Quest Aerospace      0.772  black powder    26.0       0.284  ...
# 2  Apogee Components      0.230           NaN    38.0       2.480  ...
# 3   Estes Industries      0.250  black powder    45.0       2.360  ...
# 4   Estes Industries      0.360  black powder    45.0       3.030  ...
#
#    propWeightG                           certOrg                   motorId  \
# 0         0.40  National Association of Rocketry  5f4294d20002310000000002
# 1         0.50  National Association of Rocketry  5f4294d20002310000000001
# 2         0.75  National Association of Rocketry  5f4294d20002310000000003
# 3         0.83  National Association of Rocketry  5f4294d20002310000000004
# 4         2.00  National Association of Rocketry  5f4294d20002310000000006
#
#   availability  maxThrustN totalWeightG    designation   updatedOn  type  \
# 0          OOP       1.898         1.07     MICRO_MAXX  2019-04-17    SU
# 1      regular       2.108         1.00  MICRO_MAXX_II  2019-04-17    SU
# 2          OOP       5.400          NaN          1/4A2  2019-04-17    SU
# 3      regular       4.950         6.10          1/4A3  2019-10-05    SU
# 4      regular       7.620         6.60          1/2A3  2019-10-05    SU
#
#    manufacturerAbbrev
# 0               Quest
# 1               Quest
# 2              Apogee
# 3               Estes
# 4               Estes
#
# [5 rows x 24 columns]

# %%
df_manufacturers.head(10)
# Out:
#                     name    abbrev
# 0               AeroTech  AeroTech
# 1          Alpha Hybrids     Alpha
# 2     Animal Motor Works       AMW
# 3      Apogee Components    Apogee
# 4    Cesaroni Technology  Cesaroni
# 5       Contrail Rockets  Contrail
# 6         Ellis Mountain     Ellis
# 7       Estes Industries     Estes
# 8  Gorilla Rocket Motors   Gorilla
# 9               Hypertek  Hypertek

# %%
df_e.head()
# Out:
#                                                  url description  \
# 0  https://estesrockets.com/product/000651-der-re...         NaN
# 1  https://estesrockets.com/product/000804-firehawk/         NaN
# 2  https://estesrockets.com/product/000810-220-sw...         NaN
# 3         https://estesrockets.com/product/luna-bug/         NaN
# 4  https://estesrockets.com/product/000865-mini-m...         NaN
#
#                                            image_src  \
# 0  /hc/article_attachments/8767953356173/000651_m...
# 1  /hc/article_attachments/8772192791053/Firehawk...
# 2  /hc/article_attachments/8773146657933/220_Swif...
# 3  /hc/article_attachments/8773293557261/0816-Lun...
# 4  /hc/article_attachments/8773395002637/min_mean...
#
#                            Recommended Engines Projected Max Altitude  \
# 0                 B4-2, B4-4, B6-2, B6-4, C6-5        600 ft. (183 m)
# 1            1/4A3-3T, 1/2A3-2T, A3-4T, A10-3T        550 ft. (168 m)
# 2  1/4A3-3T, 1/2A3-2T, 1/2A3-4T, A3-4T, A10-3T        850 ft. (259 m)
# 3  1/4A3-3T, 1/2A3-2T, 1/2A3-4T, A10-3T, A3-4T        800 ft. (244 m)
# 4                                A3-4T, A10-3T         225 ft. (69 m)
#
#               Recovery System              Length          Diameter  \
# 0  18 in. (45.7 cm) Parachute  16.3 in. (41.4 cm)  1.64 in. (42 mm)
# 1   6 in. (15.2 cm) Parachute  11.2 in. (28.4 cm)  0.74 in. (19 mm)
# 2               Featherweight   4.5 in. (11.4 cm)  0.54 in. (14 mm)
# 3               Featherweight    3.6 in. (9.1 cm)  0.54 in. (14 mm)
# 4   9 in. (22.9 cm) Parachute    39 in. (99.1 cm)  0.74 in. (19 mm)
#
#     Estimated Weight                            Estimated Assembly Time  ...  \
# 0     2.4 oz. (68 g)  1-3 Hours (painting and glue drying time not i...  ...
# 1  0.65 oz. (18.4 g)  1 Hour (painting and glue drying time not incl...  ...
# 2   0.09 oz. (2.5 g)  1 Hour (painting and glue drying time not incl...  ...
# 3   0.8 oz. (22.7 g)                                                NaN  ...
# 4     1.2 oz. (34 g)  1 Hour (painting and glue drying time not incl...  ...
#
#                                       Launch System Launch Rod Size  \
# 0                                               NaN             NaN
# 1  Porta-Pad II and Electron Beam Launch Controller            1/8"
# 2  Porta-Pad II and Electron Beam Launch Controller            1/8"
# 3  Porta-Pad II and Electron Beam Launch Controller            1/8"
# 4  Porta-Pad II and Electron Beam Launch Controller            1/8"
#
#                                   instructions  \
# 0  /hc/en-us/article_attachments/9445564217485
# 1  /hc/en-us/article_attachments/8772248934029
# 2  /hc/en-us/article_attachments/8773195953165
# 3  /hc/en-us/article_attachments/8773295812109
# 4  /hc/en-us/article_attachments/8773397655565
#
#                      Construction Wingspan Age Recommendation  \
# 0                             NaN      NaN                NaN
# 1                             NaN      NaN                NaN
# 2                             NaN      NaN                NaN
# 3                             NaN      NaN                NaN
# 4  High Quality Plastic Nose Cone      NaN                NaN
#
#   Launch Rod System Recovery Fin Material Estimated Assembly Weight
# 0               NaN      NaN          NaN                       NaN
# 1               NaN      NaN          NaN                       NaN
# 2               NaN      NaN          NaN                       NaN
# 3               NaN      NaN          NaN                       NaN
# 4               NaN      NaN          NaN                       NaN
#
# [5 rows x 22 columns]

# %%
df_l.head()
# Out:
#             Name                                          Image URL  \
# 0      LOC-IV 4"  https://locprecision.com/cdn/shop/products/78_...
# 1  LOC 4" Goblin  https://locprecision.com/cdn/shop/products/62_...
# 2   Yank IRIS 4"  https://locprecision.com/cdn/shop/products/YIR...
# 3         EZI-65  https://locprecision.com/cdn/shop/products/5_e...
# 4     IRIS 3.10"  https://locprecision.com/cdn/shop/products/46_...
#
#                Complexity Diameter   Height    Weight Motor Mount  \
# 0  Intermediate-Advanced       4″      47″     2lbs.   38mm with
# 1               Advanced       4″   40.75"   2.5lbs.        54mm
# 2  Intermediate-Advanced       4″      77"   5.5lbs.   54mm with
# 3     Entry-Intermediate       4″    57.75    3.2lbs   54mm with
# 4     Entry/Intermediate     3.1″     59.5   2.3lbs.         38mm
#
#   Parachute Size Shock Cord Type Shock Cord Mount  ... Vinyl Decals  \
# 0                                                  ...          NaN
# 1                                                  ...          NaN
# 2                                                  ...          NaN
# 3                                                  ...          NaN
# 4                                                  ...          NaN
#
#   Tec features Decals Fire Blanket Vinyl Decal Parachute  Fin Array Rocksim  \
# 0          NaN    NaN          NaN         NaN       NaN        NaN     NaN
# 1          NaN    NaN          NaN         NaN       NaN        NaN     NaN
# 2          NaN    NaN          NaN         NaN       NaN        NaN     NaN
# 3          NaN    NaN          NaN         NaN       NaN        NaN     NaN
# 4          NaN    NaN          NaN         NaN       NaN        NaN     NaN
#
#   Parachutes Additional Decals
# 0        NaN               NaN
# 1        NaN               NaN
# 2        NaN               NaN
# 3        NaN               NaN
# 4        NaN               NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Data Cleaning
#
# Here we handle missing values, correct data inconsistencies, and normalize the data.

# %%
# Remove cols with little data
filtered_df_e = filter_columns_by_non_null_count(df_e, 10).copy()
filtered_df_l = filter_columns_by_non_null_count(df_l, 10).copy()

# %% [markdown]
# ## Data Transformation
#
# In this section, we perform any necessary transformations such as creating new columns or reshaping the data.

# %%
filtered_df_l.rename(columns={
    'Image URL': 'image_src',
    'Product URL': 'url'},
    inplace=True)
filtered_df_e['mfgID'] = 'Estes'
filtered_df_l['mfgID'] = 'Loc'

# Concatenate the dataframes
merged_df = pd.concat([filtered_df_e, filtered_df_l], ignore_index=True)

# %%
new_rows = [{'name': 'Loc Precision', 'abbrev': 'Loc'}]

new_rows_df = pd.DataFrame(new_rows)
df_manufacturers = pd.concat([df_manufacturers, new_rows_df], ignore_index=True)

df_manufacturers.rename(columns={'abbrev': 'mfgID'}, inplace=True)

# %%
df_motors.rename(columns={'manufacturerAbbrev': 'mfgID'}, inplace=True)

# %% [markdown]
# ## Data Quality Check
#
# We re-inspect the dataset to ensure that all cleaning steps have been successful.

# %%
# Example: Re-checking the dataset
merged_df.info()
df_manufacturers.info()
df_motors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   url                      194 non-null    object
#  1   image_src                195 non-null    object
#  2   Recommended Engines      73 non-null     object
#  3   Projected Max Altitude   73 non-null     object
#  4   Recovery System          72 non-null     object
#  5   Length                   73 non-null     object
#  6   Diameter                 137 non-null    object
#  7   Estimated Weight         73 non-null     object
#  8   Estimated Assembly Time  68 non-null     object
#  9   Fin Materials            70 non-null     object
#  10  Decal Type               64 non-null     object
#  11  Launch System            69 non-null     object
#  12  Launch Rod Size          68 non-null     object
#  13  instructions             76 non-null     object
#  14  Age Recommendation       57 non-null     object
#  15  mfgID                    195 non-null    object
#  16  Name                     118 non-null    object
#  17  Complexity               44 non-null     object
#  18  Height                   37 non-null     object
#  19  Weight                   31 non-null     object
#  20  Motor Mount              39 non-null     object
#  21  Parachute Size           45 non-null     object
#  22  Shock Cord Type          39 non-null     object
#  23  Shock Cord Mount         37 non-null     object
#  24  Fin Thickness            37 non-null     object
#  25  Ring Thickness           41 non-null     object
#  26  Instructions             35 non-null     object
#  27  Price                    118 non-null    float64
#  28  Currency                 118 non-null    object
#  29  SKU                      110 non-null    object
#  30  Stock Status             118 non-null    object
#  31  Description              25 non-null     object
#  32  Links                    118 non-null    object
#  33  Parachute                33 non-null     object
#  34  Fin Array                33 non-null     object
# dtypes: float64(1), object(34)
# memory usage: 53.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    25 non-null     object
#  1   mfgID   25 non-null     object
# dtypes: object(2)
# memory usage: 528.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   commonName    1114 non-null   object
#  1   delays        715 non-null    object
#  2   diameter      1114 non-null   float64
#  3   infoUrl       194 non-null    object
#  4   totImpulseNs  1114 non-null   float64
#  5   manufacturer  1114 non-null   object
#  6   burnTimeS     1114 non-null   float64
#  7   propInfo      889 non-null    object
#  8   length        1114 non-null   float64
#  9   avgThrustN    1114 non-null   float64
#  10  dataFiles     1114 non-null   int64
#  11  impulseClass  1114 non-null   object
#  12  sparky        1114 non-null   bool
#  13  caseInfo      842 non-null    object
#  14  propWeightG   1098 non-null   float64
#  15  certOrg       1114 non-null   object
#  16  motorId       1114 non-null   object
#  17  availability  1114 non-null   object
#  18  maxThrustN    954 non-null    float64
#  19  totalWeightG  967 non-null    float64
#  20  designation   1114 non-null   object
#  21  updatedOn     1114 non-null   object
#  22  type          1114 non-null   object
#  23  mfgID         1114 non-null   object
# dtypes: bool(1), float64(8), int64(1), object(14)
# memory usage: 201.4+ KB

# %% [markdown]
# ## Exporting Cleaned Data
#
# Save the cleaned data for future use.

# %%
merged_df.to_csv('./data_clean/kits.csv', index=False)
df_manufacturers.to_csv('./data_clean/manufacturers.csv', index=False)
df_motors.to_csv('./data_clean/motors.csv', index=False)
# new_df.to_csv('estes_kits_details_cleaned.csv', index=False)
# print(new_df.info())
# Save the cleaned dataset
# df.to_csv('path/to/cleaned_dataset.csv', index=False)

# %% [markdown]
# ## Conclusion
#
# Summarize the cleaning process, note any limitations, and suggest next steps or further analysis.
